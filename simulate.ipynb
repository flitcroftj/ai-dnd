# %%
from src.game import Game

game = Game()

# %% [markdown]
# # Run Game

# %%
game.start()
# Out:
# Welcome to the Lost Mine of Phandelver campaign! This adventure is set in the land of Faerûn, in the region known as the Sword Coast. The players find themselves in the town of Phandalin, a small settlement looking to become a thriving hub of commerce again.
#
# It is a sunny morning in Phandalin, and the bustling sounds of the town fill the air. The town's mayor, Harbin Wester, has hired the party to investigate the recent increase in goblin attacks on the area and find the lost mine of the Phandelver's Pact, rumored to be a source of great wealth.
#
# As the group gathers at the town's central square, it's time for one of the players to take the lead and kick-off the adventure. Will it be Elara, Garret, Jimette bob Jr, or Jim bob Jr to start our journey?
# Elara
# ...
